# %%
import json
import pandas as pd
import urllib                             # make http requests
from pandas.io.json import json_normalize # flatten nested json

# %%
TrowBus1898 = pd.read_csv('TrowBus1898_nationality.csv', encoding='latin_1')
TrowBus1898.head()
# Out:
#    ID     CAT_MOD               Name       Address Nationality Final  \
# 0  75  Restaurant  Abbott Charles W     548 W 39th           English
# 1  76  Restaurant      Abeles Aaron   113 Eldridge            Jewish
# 2  77  Restaurant  Abelmont Eugenia    486, 6th av               NaN
# 3  78  Restaurant     Abrahams Anna     292 Cherry            Jewish
# 4  79  Restaurant  Abramowitz Louis      155 Allen            Jewish
#
#   Gender - Final CORNER         Full_Name    First        Last country1_api  \
# 0              m      N  Abbott Charles W  Charles      Abbott           GB
# 1              m      N      Abeles Aaron    Aaron      Abeles           IL
# 2              f      N  Abelmont Eugenia  Eugenia    Abelmont           ES
# 3              f      N     Abrahams Anna     Anna    Abrahams           ZA
# 4              m      N  Abramowitz Louis    Louis  Abramowitz           FR
#
#   country2_api  country_api
# 0           IE          NaN
# 1           GB          NaN
# ...

# %%
country_df = []
for i in range(783,1083):
    first = TrowBus1898['First'][i]
    last = TrowBus1898['Last'][i]
    result = !curl -X GET "https://v2.namsor.com/NamSorAPIv2/api2/json/origin/{first}/{last}" -H "accept: application/json" -H "X-API-KEY: 4945f306996d83019ed857093f895dd9"
    country_df.append(result[-1])

# %%
country_df
# Out:
# ['{"id":null,"firstName":"Martin","lastName":"Jacoby","countryOrigin":"DE","countryOriginAlt":"IE","countriesOriginTop":["DE","IE","DK","GB","FR","SE","CZ","LR","CH","SK"],"score":0.09429016799703098,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Western Europe","probabilityCalibrated":0.3436332736616422,"probabilityAltCalibrated":0.3825080030872248}',
#  '{"id":null,"firstName":"Charles","lastName":"Jacquin","countryOrigin":"FR","countryOriginAlt":"IE","countriesOriginTop":["FR","IE","BE","GB","CH","ZA","ES","KE","GH","NL"],"score":15.968502216380104,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Western Europe","probabilityCalibrated":0.8105385253034363,"probabilityAltCalibrated":0.8922822483355055}',
# ...

# %%
import numpy as np
country1 = []
country2 = []
for each in country_df:
    try:
        gen = each.split(',')[3].split(':')[1].strip('"')
        prob = each.split(',')[4].split(':')[1].strip('"')
    except:
        gen = 'error'
    
    country1.append(gen)
    country2.append(prob)
country1[:57]
# Out:
# ['DE',
#  'FR',
#  'CH',
#  'IE',
#  'IE',
#  'CH',
#  'NL',
#  'DK',
#  'AT',
#  'GB',
#  'GB',
#  'DK',
#  'DK',
#  'DE',
#  'GH',
#  'GB',
#  'IE',
#  'GB',
#  'IE',
#  'GB',
#  'GB',
#  'GB',
#  'SE',
#  'IE',
#  'IE',
#  'BD',
#  'IE',
#  'DE',
#  'DE',
#  'NO',
#  'DE',
#  'LR',
#  'DE',
#  'AT',
#  'DE',
#  'DE',
#  'IE',
#  'FR',
#  'NL',
#  'IL',
#  'CH',
#  'IE',
#  'DE',
#  'IE',
#  'IE',
#  'IE',
#  'CH',
#  'IE',
#  'IE',
#  'IE',
#  'IE',
#  'GB',
#  'IE',
#  'GB',
#  'DE',
#  'IE',
#  'IE']

# %%
TrowBus1898['country1_api'][783:840] = np.array(country1[:57])
TrowBus1898['country2_api'][783:840] = np.array(country2[:57])
# Out:
# C:\Users\Huanci\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Huanci\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
TrowBus1898[783:840]
# Out:
#        ID        CAT_MOD                                       Name  \
# 783   969     Restaurant                             Jacoby Martin
# 784   970     Restaurant                           Jacquin Charles
# 785   971     Restaurant                        Jaeger Frederick W
# 786   972     Restaurant                            Jaffee Frank S
# 787   973     Restaurant                              Janesok John
# 788   974     Restaurant                               Jann Andrew
# 789   975     Restaurant                             Jansen Albert
# 790   976     Restaurant                              Jansen Peter
# 791   977     Restaurant                            Jarossi Thomas
# 792   978     Restaurant                           Jarratt James H
# 793   979     Restaurant                             Jarvis Samuel
# 794   980     Restaurant                              Jensen Henry
# 795   981     Restaurant                             Jensen Martin
# ...

# %% [markdown]
# # 2.

# %%
country_sun = []
for i in range(840,1340):
    first = TrowBus1898['First'][i]
    last = TrowBus1898['Last'][i]
    result = !curl -X GET "https://v2.namsor.com/NamSorAPIv2/api2/json/origin/{first}/{last}" -H "accept: application/json" -H "X-API-KEY: 809321f89bfaf0c4823add36fd3331dd"
    country_sun.append(result[-1])

# %%
country_sun
# Out:
# ['{"id":null,"firstName":"Henry","lastName":"Keuling","countryOrigin":"IE","countryOriginAlt":"NL","countriesOriginTop":["IE","NL","DE","GB","DK","ZA","SE","LR","CM","GH"],"score":1.4243803244075532,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Northern Europe","probabilityCalibrated":0.46955895642549467,"probabilityAltCalibrated":0.4284104544296371}',
#  '{"id":null,"firstName":"James","lastName":"Keyes","countryOrigin":"IE","countryOriginAlt":"GB","countriesOriginTop":["IE","GB","LR","KE","GH","ZA","ES","TZ","NL","NG"],"score":11.587220750161364,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Northern Europe","probabilityCalibrated":0.712870199639778,"probabilityAltCalibrated":0.925181079883478}',
# ...

# %%
country1 = []
country2 = []
for each in country_sun:
    try:
        gen = each.split(',')[3].split(':')[1].strip('"')
        prob = each.split(',')[4].split(':')[1].strip('"')
    except:
        gen = 'error'
    
    country1.append(gen)
    country2.append(prob)
# Out:
# 'ZA'

# %%
TrowBus1898['country1_api'][840:1340] = np.array(country1)
TrowBus1898['country2_api'][840:1340] = np.array(country2)
# Out:
# C:\Users\Huanci\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Huanci\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
TrowBus1898.iloc[1339]
# Out:
# ID                                1567
# CAT_MOD                     Restaurant
# Name                 Riechers Henry J
# Address                     182 Church
# Nationality Final               German
# Gender - Final                       m
# CORNER                               N
# Full_Name             Riechers Henry J
# First                            Henry
# Last                          Riechers
# country1_api                        IE
# country2_api                        DE
# country_api                        NaN
# Name: 1339, dtype: object

# %%
country_sun1 = []
for i in range(1340,1780):
    first = TrowBus1898['First'][i]
    last = TrowBus1898['Last'][i]
    result = !curl -X GET "https://v2.namsor.com/NamSorAPIv2/api2/json/origin/{first}/{last}" -H "accept: application/json" -H "X-API-KEY: c46342164892238550d5ecf01f4e13fa"
    try:
        print(result[-1])
    except:
        break
    country_sun1.append(result[-1])
# Out:
# {"id":null,"firstName":"Henry","lastName":"Riemann","countryOrigin":"DE","countryOriginAlt":"DK","countriesOriginTop":["DE","DK","IE","CH","NL","GB","FR","IL","NO","SE"],"score":7.914365196359909,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Western Europe","probabilityCalibrated":0.584028791418287,"probabilityAltCalibrated":0.6240336547520328}
# {"id":null,"firstName":"Louis","lastName":"Rinaldi","countryOrigin":"FR","countryOriginAlt":"IT","countriesOriginTop":["FR","IT","ID","CH","ES","GB","ZA","IE","CD","HU"],"score":4.881748486099398,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Western Europe","probabilityCalibrated":0.5075058208032669,"probabilityAltCalibrated":0.8118000941380012}
# ...

# %%
country_sun1
# Out:
# ['{"id":null,"firstName":"Henry","lastName":"Riemann","countryOrigin":"DE","countryOriginAlt":"DK","countriesOriginTop":["DE","DK","IE","CH","NL","GB","FR","IL","NO","SE"],"score":7.914365196359909,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Western Europe","probabilityCalibrated":0.584028791418287,"probabilityAltCalibrated":0.6240336547520328}',
#  '{"id":null,"firstName":"Louis","lastName":"Rinaldi","countryOrigin":"FR","countryOriginAlt":"IT","countriesOriginTop":["FR","IT","ID","CH","ES","GB","ZA","IE","CD","HU"],"score":4.881748486099398,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Western Europe","probabilityCalibrated":0.5075058208032669,"probabilityAltCalibrated":0.8118000941380012}',
# ...

# %%
country1 = []
country2 = []
for each in country_sun1:
    try:
        gen = each.split(',')[3].split(':')[1].strip('"')
        prob = each.split(',')[4].split(':')[1].strip('"')
    except:
        gen = 'error'
    
    country1.append(gen)
    country2.append(prob)

# %%
len(country2)
# Out:
# 440

# %%
TrowBus1898['country1_api'][1340:1780] = np.array(country1)
TrowBus1898['country2_api'][1340:1780] = np.array(country2)
# Out:
# C:\Users\Huanci\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Huanci\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
TrowBus1898.to_csv('TrowBus1898_working.csv',index=False)

# %%
TrowBus1898
# Out:
#         ID        CAT_MOD                                Name  \
# 0       75     Restaurant                   Abbott Charles W
# 1       76     Restaurant                       Abeles Aaron
# 2       77     Restaurant                   Abelmont Eugenia
# 3       78     Restaurant                      Abrahams Anna
# 4       79     Restaurant                   Abramowitz Louis
# 5       80  Oyster Saloon                              #NAME?
# 6       81     Restaurant                      Abramson Dora
# 7       82     Restaurant                 Abromowitch Joseph
# 8       83     Restaurant                      Achorn John E
# 9       84     Restaurant                  Acierno Giacchino
# 10      85     Restaurant                     Adams Joseph T
# 11      88     Restaurant                     Ahnert Louis H
# 12      89     Restaurant                       Ahrens Henry
# 13      90     Restaurant                       Ahrens Henry
# ...

# %%
TrowBus1898[TrowBus1898['Last']=='Abeles']
# Out:
#    ID     CAT_MOD           Name       Address Nationality Final  \
# 1  76  Restaurant  Abeles Aaron   113 Eldridge            Jewish
#
#   Gender - Final CORNER     Full_Name  First    Last country1_api  \
# 1              m      N  Abeles Aaron  Aaron  Abeles           IL
#
#   country2_api  country_api
# 1           GB          NaN

# %%
TrowBus1898['Last']=TrowBus1898['Last'].apply(str)

# %%
TrowBus1898[TrowBus1898['Last']=='Smith']
# Out:
#         ID        CAT_MOD                            Name  \
# 1500  1750     Restaurant                  Smith Charles
# 1501  1751     Restaurant                Smith Elizabeth
# 1502  1752     Restaurant                 Smith Frederick
# 1503  1753     Restaurant                Smith Frederick
# 1504  1754     Restaurant  Smith George Riverside av c W
# 1505  1755     Restaurant                  Smith Henry G
# 1506  1756     Restaurant                    Smith Jacob
# 1507  1757     Restaurant                   Smith John T
# 1508  1758     Restaurant                   Smith Lucy A
# 1509  1759     Restaurant               Smith Margaret A
# 1510  1760     Restaurant                     Smith Mary
# 1511  1761     Restaurant                    Smith Sarah
# 1512  1762     Restaurant                   Smith Thomas
# 1513  1763  Oyster Saloon                          #NAME?
# 1514  1764  Oyster Saloon                          #NAME?
# ...

# %%
TrowBus1898['Last']=='Abeles'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1964    False
# 1965    False
# 1966    False
# 1967    False
# 1968    False
# 1969    False
# 1970    False
# 1971    False
# 1972    False
# 1973    False
# 1974    False
# 1975    False
# 1976    False
# 1977    False
# 1978    False
# 1979    False
# 1980    False
# 1981    False
# 1982    False
# 1983    False
# 1984    False
# 1985    False
# 1986    False
# 1987    False
# 1988    False
# 1989    False
# 1990    False
# 1991    False
# 1992    False
# 1993    False
# ...

# %%
TrowBus1898['Last'].value_counts()
# Out:
# Smith        20
# Meyer        14
# Childs       12
# DENNETT      10
# Muller        9
# Dobbins       9
# Cohen         7
# Schwartz      7
# White         7
# Miller        6
# Brown         6
# Naething      6
# Halm          6
# N             5
# Jones         5
# Feaster       5
# Weber         5
# Peragallo     5
# Klein         5
# O'Neill       5
# Jacobs        5
# Anderson      5
# Wilson        5
# Kramer        5
# McDonald      4
# McMahon       4
# Reynolds      4
# Mouquin       4
# Goldberg      4
# Lang          4
#              ..
# Mocsar        1
# Loekley       1
# Archer        1
# Schreiner     1
# Harlow        1
# Chotis        1
# Escolle       1
# Alder         1
# Bragugila     1
# Rossi         1
# Nickles       1
# Close         1
# Pigniuolo     1
# Rischow       1
# Scotti        1
# Guttman       1
# Krahm         1
# Charlon       1
# Bing          1
# Finn          1
# Loefgen       1
# Hoffer        1
# Beckhardt     1
# Dukoff        1
# ...

# %%
TrowBus1898.filter(items = ['Last'],axis = 1 )
# Out:
#              Last
# 0          Abbott
# 1          Abeles
# 2        Abelmont
# 3        Abrahams
# 4      Abramowitz
# 5          Abrams
# 6        Abramson
# 7     Abromowitch
# 8          Achorn
# 9         Acierno
# 10          Adams
# 11         Ahnert
# 12         Ahrens
# 13         Ahrens
# 14         Ahrens
# 15           Aird
# 16         Albert
# 17        Albietz
# 18          Alder
# 19     Alessandro
# 20      Allabough
# 21          Allen
# 22          Allen
# 23          Allen
# 24       Allweier
# 25     Alperstein
# 26            Alt
# 27          Alten
# 28         Altman
# 29         Amster
# ...           ...
# 1964     Stuetzle
# 1965    Suesskind
# 1966        Summa
# 1967        Sweet
# 1968       Teeter
# 1969       Tivnan
# 1970       Tivnan
# 1971       Tivnan
# 1972       Tivnan
# 1973      Toedter
# 1974     Tomsuden
# 1975       Tucker
# 1976     Vancleft
# 1977        Vidal
# 1978        Voigt
# 1979       Wagner
# 1980        Walsh
# 1981       Waubun
# ...
