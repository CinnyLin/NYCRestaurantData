# %% [markdown]
# # Ancestry 1910 ward 9
#
# Goal: Create a set of uniform code for cleaning up the street names and street numbers.

# %%
import pandas as pd

# %% [markdown]
# ## Master

# %%
DF = pd.read_csv('datasets/1880_streets_full.csv')
DF.head(1)
# Out:
#    street_name odd_on  avg_direction building_num_range  \
# 0  10th Avenue   left    -170.561731            [1, 19]
#
#                                start_end_coordinates  segment_length  \
# 0  [[40.741073, -74.009227], [40.739952, -74.0094...      126.194091
#
#    segment_direction  building_num_range_length  avg_length_per_building  \
# 0        -170.561731                         19                 6.641794
#
#    direction_deviation road_type  offset_from_road_center
# 0                  0.0    Avenue                       10

# %%
DF['street_name'].value_counts()
# Out:
# 10th Avenue          164
# 8th Avenue           148
# 2nd Avenue           129
# 5th Avenue           129
# 3rd Avenue           126
#                     ...
# Hall Place             1
# East River  N          1
# W 177th Street         1
# Blackwells  S          1
# Birmingham Street      1
# Name: street_name, Length: 666, dtype: int64

# %%
master_list = list(dict(DF['street_name'].value_counts()).keys())
master_list[:5]
# Out:
# ['10th Avenue', '8th Avenue', '2nd Avenue', '5th Avenue', '3rd Avenue']

# %% [markdown]
# ### Ward 9

# %%
df = pd.read_csv('datasets/1910_New York_Manhattan Ward 9.csv')
df.head(1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3050: DtypeWarning: Columns (6,7,21,22,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                 DataID  RecordId           Name  HouseHoldId Street Name  \
# 0  31776_4449715-00931  18527185  Mamie Rodgers     18527185   Barrow St
#
#   House Number Dwelling Number Family Number  Surname Relationship  ...  \
# 0           51               4            24  Rodgers         Wife  ...
#
#   Out of Work on April 15 Number of Weeks Out of Work Can Read Can Write  \
# 0                     NaN                         NaN      Yes       Yes
#
#   Attended School Own or Rent Home owned Farm or House  \
# 0             NaN         NaN        NaN           NaN
#
#    Survivor of Confederate or Union of Army or Navy  Blind
# ...

# %% [markdown]
# ### Street

# %% [markdown]
# Create a new column called `street_clean` than is a duplicate of current `Street Name`.
#
# "I would like that to be done in a new variable column, so that we preserve the original data."

# %%
df['street_clean'] = df['Street Name']
df.head(1)
# Out:
#                 DataID  RecordId           Name  HouseHoldId Street Name  \
# 0  31776_4449715-00931  18527185  Mamie Rodgers     18527185   Barrow St
#
#   House Number Dwelling Number Family Number  Surname Relationship  ...  \
# 0           51               4            24  Rodgers         Wife  ...
#
#   Number of Weeks Out of Work Can Read Can Write Attended School Own or Rent  \
# 0                         NaN      Yes       Yes             NaN         NaN
#
#   Home owned Farm or House Survivor of Confederate or Union of Army or Navy  \
# 0        NaN           NaN                                              NaN
#
#    Blind  street_clean
# 0    NaN     Barrow St
#
# [1 rows x 39 columns]

# %% [markdown]
# Clean `street_clean` data.

# %%
st = dict(df['street_clean'].value_counts())
#sorted(st.items())

# %% [markdown]
# Basic Clean: change "st" to "street" or add "street"

# %%
STREET = {    
    '1 Horatio St': 'Horatio Street',
    
    '13 Street': '13th Street',
    '13th Street': '13th Street',
    '13th Washington Street': '13th Washington Street',
    
    '14th Street': '14th Street',
    '15th Stoat': '15th Street',
    
    # '18 W 21 Ws 10'
    # '18 W St W 10'
    # '18 West 12 Th'
    # '1st W St Ns 10'
    # '78 St Ns 10'
    
    '4 Ave': '4th Avenue',
    '8 Ave': '8th Avenue',
    '8 St Ave': '8th Avenue',
    '8th Avenue': '8th Avenue',
    
    # '5 Rest Raeth'
    # '507 Wart Street
    # '73'
    # '80'
    
    '(Abrigador Jonar) Or': 'Abingdon Square',
    'Abrigador Jonans Or': 'Abingdon Square',
    
    # ?
    # 'Abandon'
    'Abbeville St': 'Abbeville Street',
    'Aextte Ave': 'Aextte Avenue',
    'Almwich St': 'Almwich Street',
    'Averly Pl': 'Averly Place',
    
    'Abingdon Oa': 'Abingdon Square',
    'Abingdon Pa': 'Abingdon Square',
    'Abingdon Sq': 'Abingdon Square',
    'Abingdon Squre': 'Abingdon Square',
    
    'Ac 10 St': '10th Street',
    'Al 10 St': '10th Street',
    'At 10 St': '10th Street',
    'At 10th St': '10th Street',
    
    # ?
    # 'B Cusker Street'
    'Baade Street': 'Baade Street',
    'Babtish st': 'Baptish Street',
    'Bach St': 'Bachler Street',
    'Bachler Street': 'Bachler Street',
    'Ballow Street': 'Ballow Street',
    
    'Bancker': 'Bank Street',
    'Bank St': 'Bank Street',
    'Banty': 'Bank Street',
    
    'Baford Street': 'Bedford Street',
    'Baford St': 'Bedford Street',
    'Barford': 'Bedford Street',
    'Basford Street': 'Bedford Street',
    'Beadford Street': 'Bedford Street',
    'Bedford': 'Bedford Street',
    'Bedford Store': 'Bedford Street',
    'Bedford St': 'Bedford Street',
    'Bidford St': 'Bedford Street',
    'Bodford Street': 'Bedford Street',
    'Braford Street': 'Bedford Street',
    'Buford Street': 'Bedford Street',
    'Dedford Street': 'Bedford Street',
    'Marford St': 'Bedford Street',
    
    # 'Baraboo'
    'Barith Ave': 'B Avenue',
    # 'Barra Co'
    # 'Baump Street'
    
    'Barree St': 'Barrow Street',
    'Barrier St': 'Barrow Street',
    'Barron St': 'Barrow Street',
    'Barrons Street': 'Barrow Street',
    'Barrow': 'Barrow Street',
    'Barrow St': 'Barrow Street',
    'Berry St': 'Barrow Street',
    
    'Beaver St': 'Beaver Street',
    'Beaber Street': 'Beaver Street',
    'Beaverst Pl': 'Beaver Street',
    
    # ?
    'Belsome St': 'Benson Street',
    'Blasius St': 'Blasius Street',
    'Blucher St': 'Blucher Street',
    'Butcher St': 'Butcher Street',
    
    'Bethanne Street': 'Bethune Street',
    'Bethele Street': 'Bethune Street',
    'Bethume St': 'Bethune Street',
    'Bethume Street': 'Bethune Street',
    'Bethune St': 'Bethune Street',

    'Black House': 'Bleecker Street',
    'Blacks Street': 'Bleecker Street',
    'Blacker': 'Bleecker Street',
    'Blacker Street': 'Bleecker Street',
    'Blaker St': 'Bleecker Street',
    'Blocker St': 'Bleecker Street',
    'Besecker Street': 'Bleecker Street',
    'Blecker': 'Bleecker Street',
    'Blecker St': 'Bleecker Street',
    'Blecker Street': 'Bleecker Street',
    'Bleecker St': 'Bleecker Street',
    'Bleeker': 'Bleecker Street',
    'Bleeker St': 'Bleecker Street',
    'Bleeker Street': 'Bleecker Street',
    'Bleeter': 'Bleecker Street',
    
    'Car West 11th St': '11th Street',
    
    'Caine St': 'Carmine Street',
    'Camelia': 'Carmine Street',
    'Cananea Street': 'Carmine Street',
    'Cannine St': 'Carmine Street',
    'Cannine Street': 'Carmine Street',
    'Carmane': 'Carmine Street',
    'Carmina Street': 'Carmine Street',
    'Carmine': 'Carmine Street',
    'Carmine St': 'Carmine Street',
    'Carnine Street': 'Carmine Street',
    'Caracaras Street': 'Carmine Street',
    'Cares Street': 'Carmine Street',
    'Carnmore Street': 'Carmine Street',
    
    'Castex St': 'Castle Street',
    # 'Chaddington Street'
    # 'Chalco Street'
    # 'Charhela Street'
    
    'Chamber St': 'Chambers Street',
    'Charbane St': 'Chambers Street',
    'Charbon Street': 'Chambers Street',
    
    'Chales st': 'Charles Street',
    'Chaputines Street': 'Charles Street',
    'Charlan Street': 'Charles Street',
    'Charle Street': 'Charles Street',
    'Charles': 'Charles Street',
    'Charles Str': 'Charles Street',
    'Charles St': 'Charles Street',
    'Charles street': 'Charles Street',
    'Charlos St': 'Charles Street',
    'charles street': 'Charles Street',
    
    'Chrestopker Street': 'Christopher Street',
    'Chriss St': 'Christopher Street',
    'Christoper': 'Christopher Street',
    'Christoper Street': 'Christopher Street',
    'Christophe St': 'Christopher Street',
    'Christophe Street': 'Christopher Street',
    'Christopher': 'Christopher Street',
    'Christopher St': 'Christopher Street',
    'Christopher st': 'Christopher Street',
    'Christorpher St': 'Christopher Street',
    
    'Church St': 'Church Street',
    
    # ?
    # 'Chus Apline'
    # 'Cindrich Ave'
    # 'Clackum'
    # 'Clakow St'
    # 'Cloudrest street'
    # 'Cna St'
    # 'Comber'
    # 'Comeau'
    # 'Corkum'
    #'Coursey St'
    # 'Crownmill Street'
    
    # ?
    # 'Claims Topher Street'
    # 'Clavis Topher Street'

    'Clarkes': 'Clarke Street',
    'Clarkson': 'Clarkson Street',
    'Clarkson St': 'Clarkson Street',

    'Commece St': 'Commerce Street',
    'Commerce Str': 'Commerce Street',
    'Commerce St': 'Commerce Street',
    'Commererce St': 'Commerce Street',
    'Commerse St': 'Commerce Street',
    'Cormme Street': 'Commerce Street',
    
    'Corneilus St': 'Cornelia Street',
    'Cornelia': 'Cornelia Street',
    'Cornelia St': 'Cornelia Street',
    'Cornice St': 'Cornelia Street',
    'Cornice Street': 'Cornelia Street',
    'Corvellia Street': 'Cornelia Street',
    
    'Daby Str': 'Dey Street',
    'De Roy': 'Dey Street',
    
    'Dowry Street': 'Doyers Street',
    
    'Dousay Street': 'Dousay Street',
    'Dousay street': 'Dousay Street',
    'Dounreay St': 'Dousay Street',
    
    'Dowing': 'Downing Street',
    'Dowing St': 'Downing Street',
    'Dowing Street': 'Downing Street',
    'Downing': 'Downing Street',
    'Downing St': 'Downing Street',
    'Diving Street': 'Downing Street',
    'W H': 'Downing Street',
    'W H Downing': 'Downing Street',
    
    'E 11 St': 'E 11th Street',
    'E11 St': 'E 11th Street',
    'E 11th St': 'E 11th Street',
    
    # 'Eadon St'
    # 'Eigelbach ave'

    'East S': 'E Street',
    
    'Eighth Ave': '8th Avenue',
    'Eighth Avenue': '8th Avenue',
    
    'Eleventh St and Seventh Avenue': '7th Ave & 11th St', 
    'Eleventh Street and Seventh Ave': '7th Ave & 11th St', 

    # ?
    'Elnestpher': 'Elnestpher Street',
    'Elnestpher St': 'Elnestpher Street',
    'Elnistiner': 'Elnestpher Street',
    
    # ?
    'End St': 'End Street',
    'Eng Clestel': 'End Street',
    
    # ?
    'Fones': 'Floral Street',
    'Floral Street': 'Floral Street',
    'Florero Street': 'Floral Street',
    
    'Fool Of West 10 And 11 St': 'W 10th & 11th St',
    'Fool West Tenth Street': 'W 10th & 11th St',
    'Fourteenth Street': '14th St',
    'From Cleven to Twelfth Street on Seventh Avenue': '11th St 7th Ave',
    
    # ?
    # 'Gablecrest St'
    # 'Gabrels Street'
    # 'Gag St'
    # 'Gamecock'
    
    'Crove Street': 'Grove Street',
    'Grobe Street': 'Grove Street',
    'Groue Street': 'Grove Street',
    'Grove Court': 'Grove Street',
    'Grove St': 'Grove Street',
    
    'Gamewood Street': 'Greenwich Street',
    'Gamwich Ave': 'Greenwich Avenue',
    'Gamwich Street': 'Greenwich Street',
    'Garmisch Ave': 'Greenwich Avenue',
    'Garmish': 'Greenwich Avenue',
    'Garmish Ave': 'Greenwich Avenue',
    'Garmish St': 'Greenwich Street',
    'Greenich Ave': 'Greenwich Avenue',
    'Greenich St': 'Greenwich Street',
    'Greenich Street': 'Greenwich Street',
    'Greenich street': 'Greenwich Street',
    'Greenoch St': 'Greenwich Street',
    'Greenoch Street': 'Greenwich Street',
    'Greenrich Ave': 'Greenwich Avenue',
    'Greenrich St': 'Greenwich Street',
    'Greenrich Str': 'Greenwich Street',
    'Greenview Street': 'Greenwich Street',
    'Greenwell Ave': 'Greenwich Avenue',
    'Greenwich Ave': 'Greenwich Avenue',
    'Greenwich Avenue': 'Greenwich Avenue',
    'Greenwich St': 'Greenwich Street',
    'Greenwich Street': 'Greenwich Street',
    'Greenwick st': 'Greenwich Street',
    'Greenwright Ave': 'Greenwich Avenue',
    'Greenwright Street': 'Greenwich Street',
    'Greewich Ave': 'Greenwich Avenue',
    'Greewich Avenue': 'Greenwich Avenue',
    'Greewich St': 'Greenwich Street',
    'Greewich Street': 'Greenwich Street',
    'Greinwich St': 'Greenwich Street',
    'Grenwick Ave': 'Greenwich Avenue',
    'Greebriar St': 'Greenwich Street',
    'Greemore Ave': 'Greenwich Avenue',
    'Green Wied Ave': 'Greenwich Avenue',
    'Greenaire Th Ave': 'Greenwich Avenue',
    'Greenbench St': 'Greenwich Street',
    'Greenbench Street': 'Greenwich Street',
    'Greenbrush Ave': 'Greenwich Avenue',
    'Greenbush St': 'Greenwich Street',
    'Greencrest Street': 'Greenwich Street',
    
    'Gane St': 'Gansevoort Street',
    'Gans Everst St': 'Gansevoort Street',
    'Gans Everst Street': 'Gansevoort Street',
    'Gans Roost Street': 'Gansevoort Street',
    'Ganse Voort St': 'Gansevoort Street',
    'Gansevoast St': 'Gansevoort Street',
    'Gansevoort Street': 'Gansevoort Street',
    'Gansvoort': 'Gansevoort Street',
    'Ganzevoort St': 'Gansevoort Street',
    'Gause Voort Street': 'Gansevoort Street',
    'gavzevoort st': 'Gansevoort Street',
    
    'Garrah St': 'Gay Street',
    'Garver Street': 'Gay Street',
    'Gassiert St': 'Gay Street',
    'Gay St': 'Gay Street',
    'Geary St': 'Gay Street',
    'Gehl Street': 'Gay Street',
    'Gell March St': 'Gay Street',
    'Gerry Street': 'Gay Street',

    # ?
    # 'Ginev Street'
    'Gracerock St': 'Grand Street',
    'Gracewood': 'Grand Street',
    'Gracewood Avenue': 'Grand Street',
    'Graemont Street': 'Grand Street',
    'Gramlich Ave': 'Grand Street',
    'Gramlich St': 'Grand Street',
    'Gramlich Street': 'Grand Street',
    'Grant St': 'Grand Street',
    'Grave Cazort': 'Grand Street',
    'Greacher St': 'Grand Street',
    'Greason OA St': 'Grand Street',
    'Greate St': 'Grand Street',
    'Greatnorth Ave': 'Grand Street',

    # ?
    'Haada St': 'Hague Street',
    'Haaland Street': 'Hague Street',
    'Haanapaa Street': 'Hague Street',
    'Haberern St': 'Hague Street',
    'Hacket St': 'Hague Street',
    'Hader St': 'Hague Street',
    'Hadorn': 'Hague Street',
    'Hates St': 'Hague Street',
    
    # ?
    # 'Hanlon St'
    # 'Harahan St'
    # 'Harvestor St'
    
    'Hancock': 'Hancock Street',
    
    'Handson': 'Hudson Street',
    'Handson Street': 'Hudson Street',
    'Hildson Street': 'Hudson Street',
    'Hodson': 'Hudson Street',
    'Hodson St': 'Hudson Street',
    'Hodson Street': 'Hudson Street',
    'Hudson St': 'Hudson Street',
    'Hudson Str': 'Hudson Street',
    'Hudson Street': 'Hudson Street',
    'Hudson street': 'Hudson Street',
    'Hutson St': 'Hudson Street',
    'Hudson': 'Hudson Street',
    'Huddle St': 'Hudson Street',
    'Hudack St': 'Hudson Street',
    
    'Hariton Street': 'Harrison Street',
    
    'Heater St': 'Hester Street',
    'Hedcor Street': 'Hester Street',
    'Herdener Street': 'Hester Street',
    
    'Horacio St': 'Horatio Street',
    'Horale St': 'Horatio Street',
    'Horatio St': 'Horatio Street',
    'Horatio St Rear': 'Horatio Street',
    'Horatio Street': 'Horatio Street',
    'Horatio st': 'Horatio Street',
    'Hornton Street': 'Horatio Street',
    'W Hornton St': 'Horatio Street',
    'Labor Locatio': 'Horatio Street',
    'Locatio St': 'Horatio Street',
    
    'West Houston': 'Houston Street W',
    'West Houston St': 'Houston Street W',
    'West Houston Street': 'Houston Street W',
 
    # 'Interloch St'
    
    'Jaan St': 'Jane Street',
    'Jane Ave': 'Jane Street',
    'Jane St': 'Jane Street',
    'Jane Street': 'Jane Street',
    'Jant Street': 'Jane Street',
    
    'Jones': 'Jones Street',
    'Jones St': 'Jones Street',
    
    'Jace': 'James Street',
    'Jace St': 'James Street',
    'Jacie street': 'James Street',
    'Jam Street': 'James Street',

     # 'Jarvist Ave'
     
     'Jefferson Market City Parson': 'Jefferson Street',
     'Jefferson Market City Prison': 'Jefferson Street',
     'Johanson': 'John Street',
     
    'Kee St': 'King Street',
    
    'Lacoy St': 'Leroy Street',
    'Lacoy Street': 'Leroy Street',
    'Laroy': 'Leroy Street',
    'Le Roy': 'Leroy Street',
    'Le Roy St': 'Leroy Street',
    'Leewal Ave': 'Leroy Street',
    'Leovey St': 'Leroy Street',
    'Leray St': 'Leroy Street',
    'Leray Street': 'Leroy Street',
    'Leray st': 'Leroy Street',
    'Leroy St': 'Leroy Street',
    'Leroy Street': 'Leroy Street',
    'Leroy Strret': 'Leroy Street',
    'Lery St': 'Leroy Street',
    
    'Liller 12 St': 'Little West 12th Street',
    'Litlle West 12 St': 'Little West 12th Street',
    'Little West 12 St': 'Little West 12th Street',
    'Little West 12th St': 'Little West 12th Street',
    
    #'Maratic'
    # 'Maxam St'
    
    'Madon St': 'Madison Street',
    
    'Milligan Place': 'Milligan Place',
    
    'Morton': 'Morton Street',
    'Morton St': 'Morton Street',
    'Morton Street': 'Morton Street',
    
    # 'Nasty'
    # 'Nort 4th Street' 
    # 'Norton Street'
    # 'Novel St'
    
    # 'Ohala'
    # 'Olauniu'
    
    'Parry Str': 'Perry Street',
    'Parry Street': 'Perry Street',
    'Peery Street': 'Perry Street',
    'Peny': 'Perry Street',
    'Peny St': 'Perry Street',
    'Peral st': 'Perry Street',
    'Perrer Street': 'Perry Street',
    'Perry St': 'Perry Street',
    'Perry Str': 'Perry Street',
    'Perry Street': 'Perry Street',
    'Perry street': 'Perry Street',
    'Pery': 'Perry Street',
    'Pery Rear': 'Perry Street',
    'Pery St': 'Perry Street',
    'perry street': 'Perry Street',
    
    'Patchee Place': 'Patchin Place',
    'Patchen Place': 'Patchin Place',
    'patchen place': 'Patchin Place',
    
    # 'Payer'
    #'Pheshing Ton'
    # 'Plucker'
    #'Pung St'
    
    # 'Quigly Pl'
    
    'Ras': 'Rose Street',
    # 'Rest 11th Street'
    # 'Restaurant'
    # 'Root'
    
    # 'Sacalait 4th M'
    # 'Sacre Abandon Sauce'
    # 'Serry Street'
    # 'Sivley Place'
    
    'Seventh Ave': '7th Avenue',
    'Seventh Avenue': '7th Avenue',
    'Sixth Ave': '6th Avenue',
    'Sixth Avenue': '6th Avenue',
    'Sixthe Ave': '6th Avenue',
    # 'South Avenue'
    
    # 'Spot Forth'
    # 'St 14th St'
    # 'St Acie St'
    
    'Srevice Street': 'Service Street',
    
    'St Linker Place': "Saint Luke's Place",
    'St Luke Place': "Saint Luke's Place",
    'St Lukes Place': "Saint Luke's Place",
    'St Lukia Pl': "Saint Luke's Place",
    # 'St Vincents Hospital Eleventh St Seventh Ave'
    
    # 'Steamship Alamo Fool West Tenth Street Willsey Arrel'
    # 'Steamship Colorado Fool West Tenth Street'
    # 'Steamship Demer Fool West Tenth Street'
    # 'Steamship Wymosa Foot Of West 11 St'
    # 'Stemen St Vacio'
    # 'Str Pa'
    # 'Street'
    # 'Street 4 & St'
    
    # 'Taas St'
    # 'Tuker'
    'Tane St': 'Thames Street',
    'Toot 11th Street': 'Toot Street',
    'Toot Bank St': 'Toot Street',
    'Toot W 11th St': 'Toot Street',
    'Toot West 11th Sheet S S Prantes': 'Toot Street',
    'Toot West 11th Stat Stewer Eel Valle': 'Toot Street',
    
    'Van Nest Place': 'Vannest Place',
    'Van West Place': 'Vannest Place',
    
    'Vancik': 'Varick Street',
    'Vancik Street': 'Varick Street',
    'Vanrick St': 'Varick Street',
    'Vanrick Street': 'Varick Street',
    'Varick Street': 'Varick Street',
    
    # 'Wable'
    # 'Wallsmith'
    
    'Wackerly Place': 'Waverly Place',
    'Waderky St': 'Waverly Place',
    'Wakely Pl': 'Waverly Place',
    'Wanley Place': 'Waverly Place',
    'Warbaby Pl': 'Waverly Place',
    'Warley Place': 'Waverly Place',
    'Waveney Place WN St': 'Waverly Place',
    'Waverley Pl': 'Waverly Place',
    'Waverley Place': 'Waverly Place',
    'Waverly Place': 'Waverly Place',
    'Waverly St': 'Waverly Place',
    
    'Wait 10': 'White Street',
    'Wait 12 Street': 'White Street',
    
    # 'Warick'
    # 'Warick Street'
    # 'Wastewater Street'
    # 'Wealthy St'
    # 'Wrigth'
    
    'Wash Pl': 'Washington Place',
    'Washington Pl': 'Washington Place',
    'Washington Place': 'Washington Place',
    'Wash St': 'Washington Street',
    'Washing 6th': 'Washington Street',
    'Washing An St': 'Washington Street',
    'Washing St': 'Washington Street',
    'Washing Str': 'Washington Street',
    'Washing Ton': 'Washington Street',
    'Washing Tor St': 'Washington Street',
    'Washingtion': 'Washington Street',
    'Washingtion St': 'Washington Street',
    'Washingtion Street': 'Washington Street',
    'Washington': 'Washington Street',
    'Washington 13th Street': 'Washington Street',
    'Washington St': 'Washington Street',
    'Washington Street': 'Washington Street',
    'Washington street': 'Washington Street',
    'Washinton': 'Washington Street',
    'Washinton Street': 'Washington Street',
    'Wastach 11th st': 'Washington Street',
    
    'Weehawken Street': 'Weehawken Street',

    'Wentworth Wart': 'Worth Street',
    'Werth Str': 'Worth Street',
    
    'Westhall St': 'Whitehall Street',

    
    # 'W W 21 Ns 12'
    # 'West Luckte St'
    # 'West South'
    # 'West South Street'
    # 'West Walworth Street'
    # 'West Spector St'
    
    'W St': 'West Street',
    'West': 'West Street',
    'West St': 'West Street',
    'West Street': 'West Street',
    'West street': 'West Street',
    'weat St': 'West Street',
    
    'W 10 St': 'W 10th Street',
    'W 10 Street': 'W 10th Street',
    'W 10th St': 'W 10th Street',
    'West 10': 'W 10th Street',
    'West 10 St': 'W 10th Street',
    'West 10 Street': 'W 10th Street',
    'West 10th': 'W 10th Street',
    'West 10th Haint': 'W 10th Street',
    'West 10th St': 'W 10th Street',
    'West 10th Street': 'W 10th Street',
    'West Tenth Street': 'W 10th Street',
    
    'W 11 St': 'W 11th Street',
    'W 11 Street': 'W 11th Street',
    'W 11th St': 'W 11th Street',
    'W 11th Street': 'W 11th Street',
    'West 11st': 'W 11th Street',
    'West 11th': 'W 11th Street',
    'West 11th St': 'W 11th Street',
    'West 11th Street': 'W 11th Street',
    'West Eleventh St': 'W 11th Street',
    'West Eleventh Street': 'W 11th Street',
    'West Elsworth Street': 'W 11th Street',
    
    'W 12 St': 'W 12th Street',
    'W 12th St': 'W 12th Street',
    'West 12 St': 'W 12th Street',
    'West 12 Street': 'W 12th Street',
    'West 12 st': 'W 12th Street',
    'West 12th St': 'W 12th Street',
    'West 12th Street': 'W 12th Street',
    'west 12 street': 'W 12th Street',
    'west 12th st': 'W 12th Street',
    
    'W 13 St': 'W 13th Street',
    'W 13th': 'W 13th Street',
    'W 13th St': 'W 13th Street',
    'West 13 St': 'W 13th Street',
    'West 13 Street': 'W 13th Street',
    'West 13th St': 'W 13th Street',
    'West 13th Street': 'W 13th Street',
    'West Thirteenth St': 'W 13th Street',
    'West Thirteenth Street': 'W 13th Street',
    
    'W 14 St': 'W 14th Street',
    'W 14th St': 'W 14th Street',
    'West 14 St': 'W 14th Street',
    'West 14th St': 'W 14th Street',
    'West 14th Street': 'W 14th Street',
    'West Forseth Street': 'W 14th Street',
    'West Fourteenth Street': 'W 14th Street',
    
    'W 4 St': 'W 4th Street',
    'W 4 Street': 'W 4th Street',
    'W 4th St': 'W 4th Street',
    'W 4th Street': 'W 4th Street',
    'W Fourth St': 'W 4th Street',
    'West 4': 'W 4th Street',
    'West 4 St': 'W 4th Street',
    'West 4th': 'W 4th Street',
    'West 4th St': 'W 4th Street',
    'West 4th Street': 'W 4th Street',
    'West Fourth': 'W 4th Street',
    'West Fourth St': 'W 4th Street',
    'w 4th St': 'W 4th Street',
    
    'West Airth St': 'W 8th Street',
    
    'W 21st Street': 'W 21st Street',
    
    'W 45 St': 'W 45th Street'
}

# %%
df = df.replace({'street_clean': STREET})
df.head(1)
# Out:
#                 DataID  RecordId           Name  HouseHoldId Street Name  \
# 0  31776_4449715-00931  18527185  Mamie Rodgers     18527185   Barrow St
#
#   House Number Dwelling Number Family Number  Surname Relationship  ...  \
# 0           51               4            24  Rodgers         Wife  ...
#
#   Number of Weeks Out of Work Can Read Can Write Attended School Own or Rent  \
# 0                         NaN      Yes       Yes             NaN         NaN
#
#   Home owned Farm or House Survivor of Confederate or Union of Army or Navy  \
# 0        NaN           NaN                                              NaN
#
#    Blind   street_clean
# 0    NaN  Barrow Street
#
# [1 rows x 39 columns]

# %%
streets_list = list(dict(df['street_clean'].value_counts()).keys())
streets_list[:5]
# Out:
# ['Hudson Street',
#  'Perry Street',
#  'W 11th Street',
#  'W 10th Street',
#  'Washington Street']

# %% [markdown]
# ### Cross check results
#
# After basic clean, check `street_clean` results with master list and revise `STREET` dict.

# %%
for street in streets_list:
    if street not in master_list:
        print(street)
# Out:
# 13th Street
# Service Street
# Clackum
# 10th Street
# 14th St
# Elnestpher Street
# Street
# Saint Luke's Place
# Dousay Street
# West South Street
# 14th Street
# 8th Ave
# 7th Ave & 11th St
# St Vincents Hospital Eleventh St Seventh Ave
# Toot Street
# Floral Street
# Barron Street
# Comeau
# W 10th & 11th St
# Blacker St
# Claims Topher Street
# 18 West 12 Th
# Steamship Wymosa Foot Of West 11 St
# Comber
# Dousay St
# 18 W 21 Ws 10
# Chalco Street
# Spot Forth
# Ginev Street
# 11th St 7th Ave
# 1st W St Ns 10
# Coursey St
# 18 W St W 10
# West Walworth Street
# Olauniu
# Chaddington Street
# 78 St Ns 10
# Eadon St
# W 8th Street
# Maratic
# Averly Place
# Gag St
# Nort 4th Street
# Gabrels Street
# Bachler Street
# Steamship Alamo Fool West Tenth Street Willsey Arrel
# Quigly Pl
# Norton Street
# Charbon St
# Street 4 & St
# Nasty
# Steamship Colorado Fool West Tenth Street
# End Street
# Clavis Topher Street
# Cloudrest street
# Rest 11th Street
# Warick
# Baade Street
# ...

# %%
#sorted(master_list)

# %% [markdown]
# ### House Number
#
# I suddenly have a feeling that is `'2.0'` '2' or '20'?

# %%
df['num_clean'] = df['House Number']
df.head(1)
# Out:
#                 DataID  RecordId           Name  HouseHoldId Street Name  \
# 0  31776_4449715-00931  18527185  Mamie Rodgers     18527185   Barrow St
#
#   House Number Dwelling Number Family Number  Surname Relationship  ...  \
# 0           51               4            24  Rodgers         Wife  ...
#
#   Can Read Can Write Attended School Own or Rent Home owned Farm or House  \
# 0      Yes       Yes             NaN         NaN        NaN           NaN
#
#   Survivor of Confederate or Union of Army or Navy Blind   street_clean  \
# 0                                              NaN   NaN  Barrow Street
#
#    num_clean
# 0         51
#
# [1 rows x 40 columns]

# %%
no = dict(df['num_clean'].value_counts())
sorted(no.items())
# Out:
# [('0', 20),
#  ('0.0', 9),
#  ('1', 156),
#  ('1 1/2', 10),
#  ('1.0', 55),
#  ('1/12', 1),
#  ('10', 289),
#  ('10-12', 76),
#  ('10-21', 37),
#  ('10-32', 41),
#  ('10.0', 98),
#  ('100', 48),
#  ('100.0', 20),
#  ('101', 147),
#  ('101.0', 40),
#  ('102', 37),
#  ('102.0', 52),
#  ('103', 84),
#  ('103-5', 29),
#  ('103.0', 26),
#  ('1035', 58),
#  ('1039.0', 50),
#  ('104', 75),
#  ('104.0', 47),
#  ('105', 37),
#  ('105.0', 35),
#  ('106', 39),
#  ('106.0', 250),
#  ('107', 24),
#  ('107.0', 99),
#  ('1079.0', 4),
#  ('108', 47),
#  ('108.0', 170),
#  ('109', 55),
#  ('109.0', 24),
#  ('11', 289),
#  ('11.0', 86),
#  ('110', 36),
#  ('110 Rear', 11),
#  ('110.0', 191),
#  ('111', 15),
#  ('111.0', 147),
#  ('1111', 36),
#  ('112', 13),
#  ('112.0', 45),
#  ('113', 112),
#  ('113.0', 84),
#  ('1132.0', 8),
#  ('114', 63),
#  ('114.0', 51),
#  ('115', 77),
#  ('115.0', 95),
#  ('116', 40),
#  ('116.0', 128),
#  ('117', 238),
#  ('117.0', 146),
#  ('118', 54),
#  ('118.0', 83),
# ...

# %%
NUMBER = {
    '0.0': '0',
    
    '1 1/2': '1',
    '1.0': '1',
    '1/12': '1',
    
    '10-12': '10',
    '10-21': '10',
    '10-32': '10',
    '10.0': '10',
    
    '100.0': '100',
    '101.0': '101',
    '102.0': '102',
    '104.0': '104',
    '105.0': '105',
    '106.0': '106',
    '107.0': '107',
    '1079.0': '107',
    '108.0': '108',
    '109.0': '109',
    
    '103-5': '103',
    '103.0': '103',
    '1035': '103',
    '1039.0': '103',
    
    '11.0': '11',
    '1111': '11',
    '1132.0': '11',
    
    '110 Rear': '110',
    '110.0': '110',
    
    '111.0': '111',
    '112.0': '112',
    '113.0': '113',
    '114.0': '114',
    '115.0': '115',
    '116.0': '116',
    '117.0': '117',
    '118.0': '118',
    '119 1/2': '119',
    '119.0': '119',
    
    '12 B'
    '12 F'
    '12-8'
    '12.0'
    '1214'
    
    
    '120 Rear'
    '120.0'
    
    '121.0'
    '122.0'
    '123.0'
    '124.0'
    '125.0'
    '126.0'
    '127.0', 44), ('128', 60), ('128.0', 26), ('129', 185), ('129.0', 67), ('13', 437), ('13 1/2', 9), ('13.0', 63), ('130', 22), ('130.0', 34), ('131', 106), ('131 1/2', 28), ('131.0', 12), ('132', 34), ('132 1/2', 4), ('132.0', 32), ('133', 82), ('133.0', 67), ('134', 105), ('134.0', 10), ('1343', 5), ('135', 55), ('135-51', 7), ('135.0', 42), ('136', 31), ('136.0', 54), ('137', 88), ('137.0', 45), ('138', 76), ('138.0', 24), ('139', 72), ('139.0', 36), ('14', 245), ('14 Rear', 23), ('14.0', 22), ('140', 90), ('140.0', 34), ('141', 47), ('141.0', 6), ('142', 23), ('142.0', 26), ('143', 108), ('143.0', 35), ('144', 81), ('144.0', 21), ('145', 44), ('145.0', 15), ('146', 89), ('146.0', 21), ('147', 120), ('147.0', 20), ('148', 56), ('148.0', 27), ('149', 34), ('149.0', 82), ('15', 374), ('15 Rear', 8), ('15.0', 70), ('150', 66), ('150.0', 37), ('151', 18), ('151.0', 28), ('152.0', 88), ('153', 11), ('153.0', 28), ('154', 10), ('154.0', 43), ('155', 14), ('155.0', 16), ('1554', 22), ('156', 33), ('156.0', 16), ('157', 5), ('157.0', 36), ('158', 33), ('158.0', 15), ('159', 27), ('159.0', 32), ('16', 331), ('16 1/2', 133), ('16 1/2 Rear 4', 23), ('16 R', 31), ('16.0', 40), ('160', 20), ('160.0', 25), ('1602', 11), ('161', 48), ('161.0', 89), ('162', 22), ('162.0', 43), ('163', 120), ('163.0', 28), ('164', 45), ('164.0', 6), ('165', 188), ('165-169', 20), ('165.0', 33), ('1659', 11), ('166', 74), ('167', 148), ('167.0', 64), ('168', 13), ('168-170', 11), ('169', 12), ('169-70', 50), ('169.0', 56), ('17', 262), ('17.0', 131), ('170', 46), ('170-168', 50), ('171', 15), ('171-3', 11), ('171.0', 48), ('1713', 32), ('172', 16), ('173', 10), ('173.0', 50), ('174', 712), ('174.0', 5), ('1744', 29), ('1745', 2), ('1746', 37), ('175', 20), ('175.0', 40), ('176', 155), ('176.0', 27), ('177', 31), ('177.0', 51), ('178', 139), ('178.0', 6), ('179', 49), ('179.0', 7), ('18', 528), ('18-14', 22), ('18-14 Rear', 2), ('18.0', 23), ('180', 32), ('180.0', 10), ('181', 76), ('182', 61), ('183.0', 23), ('184', 47), ('184.0', 58), ('185', 31), ('186', 378), ('187', 20), ('187.0', 3), ('188', 1), ('189', 16), ('189.0', 58), ('19', 445), ('19.0', 105), ('190', 47), ('190.0', 29), ('
832.0', 11), ('834.0', 32), ('835.0', 34), ('836.0', 37), ('84', 25), ('84.0', 152), ('841', 29), ('842.0', 57), ('843', 16), ('844.0', 49), ('846', 41), ('85', 105), ('85.0', 79), ('851', 2), ('86', 59), ('86.0', 148), ('860.0', 1), ('863.0', 7), ('865.0', 4), ('866', 20), ('87', 46), ('87.0', 92), ('872', 25), ('88', 21), ('88.0', 156), ('89', 27), ('89.0', 112), ('891', 46), ('897', 38), ('9', 299), ('9 1/2', 1), ('9.0', 76), ('90', 35), ('90.0', 115), ('90/98', 58), ('902', 30), ('91', 37), ('91.0', 159), ('911', 3), ('912.0', 10), ('92', 47), ('92.0', 116), ('93', 81), ('93.0', 80), ('94', 50), ('94.0', 51), ('946', 20), ('95', 65), ('95.0', 48), ('96', 27), ('96.0', 141), ('96/98', 10), ('97', 78), ('97.0', 13), ('98', 65), ('98.0', 48), ('99', 79), ('99 Rear', 9), ('99.0', 19), ('993.0', 9), ('Boat', 36), ('Rear', 33)
}

# %%
df = df.replace({'num_clean': NUMBER})
df.head(1)
# Out:
#           DataID  RecordId          Name  HouseHoldId          Street Name  \
# 0  4449800_00423  18500383  Margaret Dow     18500383  West Houston Street
#
#   House Number Dwelling Number  Family Number Surname Relationship  ...  \
# 0          279             1.0            1.0     Dow         Head  ...
#
#   Can Write Attended School Own or Rent Home owned Farm or House  \
# 0       Yes             NaN        Rent        NaN         House
#
#   Survivor of Confederate or Union of Army or Navy Blind Deaf and Dumb  \
# 0                                              NaN   NaN           NaN
#
#    street_clean  num_clean
# 0  W Houston St        279
#
# [1 rows x 41 columns]

# %% [markdown]
# geocoding with `qGIS`'s `MMQGIS` requires four columns: `Address`, `City`, `State`, `Country`

# %%
df['Address'] = df['num_clean'].astype(str) + ' ' + df['street_clean']
df.head(1)
# Out:
#                 DataID  RecordId           Name  HouseHoldId Street Name  \
# 0  31776_4449715-00931  18527185  Mamie Rodgers     18527185   Barrow St
#
#   House Number Dwelling Number Family Number  Surname Relationship  ...  \
# 0           51               4            24  Rodgers         Wife  ...
#
#   Can Write Attended School Own or Rent Home owned Farm or House  \
# 0       Yes             NaN         NaN        NaN           NaN
#
#   Survivor of Confederate or Union of Army or Navy Blind   street_clean  \
# 0                                              NaN   NaN  Barrow Street
#
#    num_clean           Address
# 0         51  51 Barrow Street
#
# [1 rows x 41 columns]

# %%
df['City'] = 'New York City'
df['State'] = 'New York'
df['Country'] = 'United States'
df.head(1)
# Out:
#                 DataID  RecordId           Name  HouseHoldId Street Name  \
# 0  31776_4449715-00931  18527185  Mamie Rodgers     18527185   Barrow St
#
#   House Number Dwelling Number Family Number  Surname Relationship  ...  \
# 0           51               4            24  Rodgers         Wife  ...
#
#   Home owned Farm or House Survivor of Confederate or Union of Army or Navy  \
# 0        NaN           NaN                                              NaN
#
#   Blind   street_clean num_clean           Address           City     State  \
# 0   NaN  Barrow Street        51  51 Barrow Street  New York City  New York
#
#          Country
# 0  United States
#
# [1 rows x 44 columns]

# %%
#df.to_csv('cleaned/ward8_1910_CLEANED.csv')
