# %% [markdown]
# # Using API to get nationality
#
# Account: ycl461+1@nyu.edu

# %%
import json
import pandas as pd
import numpy as np
import urllib                             
from pandas.io.json import json_normalize
from collections import Counter

# %%
TrowBus1913 = pd.read_csv('1913TrowBus_nationalityAPI.csv', encoding='latin_1')
TrowBus1913.head(1)
# Out:
#               Year   PG  ID                 ID2      CAT_ORG  \
# 0  1913_TrowBusMan  904  33  1913_TrowBusMan_33  Restaurants
#
#                                FULL  Position Nation                   Name  \
# 0  Albanian Roumanian Co, 261 W37th        23    NaN  Albanian Roumanian Co
#
#   NATIONALITY  ... ST Name 2 ST Name 3 ST Name 4 ST Name 5 ST Name 6  \
# 0    Albanian  ...     W37th       NaN       NaN       NaN       NaN
#
#        First      Last country1_api country2_api origin_api
# 0  Roumanian  Albanian      Romania         Iran        NaN
#
# [1 rows x 28 columns]

# %%
TrowBus1913.columns
# Out:
# Index(['Year', 'PG', 'ID', 'ID2', 'CAT_ORG', 'FULL', 'Position', 'Nation',
#        'Name', 'NATIONALITY', 'NATIONALITY final', 'GENDER', 'Unnamed: 12',
#        'Addy_Clean', 'Address', 'CORNER', 'ST combi', 'ST Name', 'ST Name 2',
#        'ST Name 3', 'ST Name 4', 'ST Name 5', 'ST Name 6', 'First', 'Last',
#        'country1_api', 'country2_api', 'origin_api'],
#       dtype='object')

# %% [markdown]
# Create a new column based on existing columns.
#
# `df['new_col'] = df['old_col']`

# %%
TrowBus1913['First'] = TrowBus1913['Name'].str.split().str[1]
TrowBus1913['Last'] = TrowBus1913['Name'].str.split().str[0]
TrowBus1913.head(1)
# Out:
#               Year   PG  ID                 ID2      CAT_ORG  \
# 0  1913_TrowBusMan  904  33  1913_TrowBusMan_33  Restaurants
#
#                                FULL  Position Nation                   Name  \
# 0  Albanian Roumanian Co, 261 W37th        23    NaN  Albanian Roumanian Co
#
#   NATIONALITY  ... ST Name 2 ST Name 3 ST Name 4 ST Name 5 ST Name 6  \
# 0    Albanian  ...     W37th       NaN       NaN       NaN       NaN
#
#        First      Last country1_api country2_api origin_api
# 0  Roumanian  Albanian      Romania         Iran        NaN
#
# [1 rows x 28 columns]

# %%
country_df = []
for i in range(0,499):
    first = TrowBus1913['First'][i]
    last = TrowBus1913['Last'][i]
    result = !curl -X GET "https://v2.namsor.com/NamSorAPIv2/api2/json/origin/{first}/{last}" -H "accept: application/json" -H "X-API-KEY: 5fe4dfb2938c5ebdaec25dc955df5da3"
    country_df.append(result[-1])

# %%
country_df
# Out:
# ['{"id":null,"firstName":"Roumanian","lastName":"Albanian","countryOrigin":"RO","countryOriginAlt":"IR","countriesOriginTop":["RO","IR","ES","ID","NE","SA","BJ","FR","IE","GB"],"score":2.538615218508499,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Eastern Europe","probabilityCalibrated":0.4941407300612068,"probabilityAltCalibrated":0.4855697361879379}',
#  '{"id":null,"firstName":"Emily","lastName":"Garbade","countryOrigin":"IE","countryOriginAlt":"GB","countriesOriginTop":["IE","GB","FR","ES","KE","DE","IT","PT","ZA","NG"],"score":1.7136952067798936,"regionOrigin":"Europe","topRegionOrigin":"Europe","subRegionOrigin":"Northern Europe","probabilityCalibrated":0.4779626147690672,"probabilityAltCalibrated":0.6523798500077853}',
# ...

# %%
file = open('api500.txt','w')
file.writelines(country_df)
file.close()

# %% [markdown]
# Not sure what is wrong with this chunck of code but I had to do this separately for it to work.
#
# `country1 = []
# country2 = []
# score = []
# region = []
# prob1 = []
# prob2 = []
#
# for each in country_df:
#     try:
#         country1.append(each.split(',')[3].split(':')[1].strip('"')) #"countryOrigin"
#         country2.append(each.split(',')[4].split(':')[1].strip('"')) #"countryOriginAlt"
#         score.append(each.split(',')[15].split(':')[1]) #"score"
#         region.append(each.split(',')[18].split(':')[1].strip('"')) #"subRegionOrigin"
#         prob1.append(each.split(',')[19].split(':')[1]) #"probabilityCalibrated"
#         prob2.append(each.split(',')[20].split(':')[1]) #"probabilityAltCalibrated"
#     except:
#         country1.append('error')
#         country2.append('error')
#         score.append('error')
#         region.append('error')
#         prob1.append('error')
#         prob2.append('error')`

# %%
country1 = []

for each in country_df:
    try:
        country1.append(each.split(',')[3].split(':')[1].strip('"')) #"countryOrigin"
    except:
        country1.append('error')
country1[:5]
# Out:
# ['RO', 'IE', 'IL', 'NE', 'IE']

# %%
country2 = []

for each in country_df:
    try:
        country2.append(each.split(',')[4].split(':')[1].strip('"')) #"countryOriginAlt"
    except:
        country2.append('error')
country2[:5]
# Out:
# ['IR', 'GB', 'IT', 'IL', 'GB']

# %%
score = []

for each in country_df:
    try:
        score.append(each.split(',')[15].split(':')[1]) #"score"
    except:
        score.append('error')
score[:5]
# Out:
# ['2.538615218508499',
#  '1.7136952067798936',
#  '5.869706884538468',
#  '1.6990627534822467',
#  '10.402583873485904']

# %%
region = []

for each in country_df:
    try:
        region.append(each.split(',')[18].split(':')[1].strip('"')) #"subRegionOrigin"
    except:
        region.append('error')
region[:5]
# Out:
# ['Eastern Europe',
#  'Northern Europe',
#  'Western Asia',
#  'Western Africa',
#  'Northern Europe']

# %%
prob1 = []

for each in country_df:
    try:
        prob1.append(each.split(',')[19].split(':')[1]) #"probabilityCalibrated"
    except:
        prob1.append('error')
prob1[:5]
# Out:
# ['0.4941407300612068',
#  '0.4779626147690672',
#  '0.5106875922797753',
#  '0.4775753758707192',
#  '0.6798921855343782']

# %%
prob2 = []

for each in country_df:
    try:
        prob2.append(each.split(',')[20].split(':')[1]) #"probabilityAltCalibrated"
    except:
        prob2.append('error')
prob2[:5]
# Out:
# ['0.4855697361879379}',
#  '0.6523798500077853}',
#  '0.573119629535321}',
#  '0.44236361411144437}',
#  '0.6869777625428424}']

# %%
#check
len(country1)==len(country2)==len(score)==len(region)==len(prob1)==len(prob2)
# Out:
# True

# %% [markdown]
# Create a new empty column.
#
# `import numpy as np`
#
# `df['new_col'] = np.nan`

# %%
TrowBus1913['country1_api'] = np.nan
TrowBus1913['country2_api'] = np.nan
TrowBus1913['score_api'] = np.nan
TrowBus1913['region_api'] = np.nan
TrowBus1913['prob1_api'] = np.nan
TrowBus1913['prob2_api'] = np.nan

# %%
TrowBus1913.head(1)
# Out:
#               Year   PG  ID                 ID2      CAT_ORG  \
# 0  1913_TrowBusMan  904  33  1913_TrowBusMan_33  Restaurants
#
#                                FULL  Position Nation                   Name  \
# 0  Albanian Roumanian Co, 261 W37th        23    NaN  Albanian Roumanian Co
#
#   NATIONALITY  ... ST Name 6      First      Last country1_api country2_api  \
# 0    Albanian  ...       NaN  Roumanian  Albanian          NaN          NaN
#
#   origin_api score_api region_api prob1_api prob2_api
# 0        NaN       NaN        NaN       NaN       NaN
#
# [1 rows x 32 columns]

# %%
TrowBus1913['country1_api'][0:499] = np.array(country1[:499])
TrowBus1913['country2_api'][0:499] = np.array(country2[:499])
TrowBus1913['score_api'][0:499] = np.array(score[:499])
TrowBus1913['region_api'][0:499] = np.array(region[:499])
TrowBus1913['prob1_api'][0:499] = np.array(prob1[:499])
TrowBus1913['prob2_api'][0:499] = np.array(prob2[:499])
# Out:
# <ipython-input-75-dfbfc2244e35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TrowBus1913['country1_api'][0:499] = np.array(country1[:499])
# <ipython-input-75-dfbfc2244e35>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TrowBus1913['country2_api'][0:499] = np.array(country2[:499])
# <ipython-input-75-dfbfc2244e35>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
TrowBus1913.head(1)
# Out:
#               Year   PG  ID                 ID2      CAT_ORG  \
# 0  1913_TrowBusMan  904  33  1913_TrowBusMan_33  Restaurants
#
#                                FULL  Position Nation                   Name  \
# 0  Albanian Roumanian Co, 261 W37th        23    NaN  Albanian Roumanian Co
#
#   NATIONALITY  ... ST Name 6      First      Last country1_api country2_api  \
# 0    Albanian  ...       NaN  Roumanian  Albanian           RO           IR
#
#   origin_api          score_api      region_api           prob1_api  \
# 0        NaN  2.538615218508499  Eastern Europe  0.4941407300612068
#
#              prob2_api
# 0  0.4855697361879379}
#
# [1 rows x 32 columns]

# %% [markdown]
# Replace data values in python.
#
# [pandas.DataFrame.replace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html)
#
# `DataFrame.replace(self, to_replace=None, value=None, inplace=False, limit=None, regex=False, method='pad')[source]`
#
# Parameters: to_replace: str, regex, list, dict, Series, int, float, or None
#
# **dict**
#
# For a DataFrame nested dictionaries, e.g., `{'a': {'b': np.nan}}`, are read as follows: look in column `‘a’` for the value `‘b’` and replace it with `NaN`. The value parameter should be None to use a nested dict in this way. You can nest regular expressions as well. Note that column names (the top-level dictionary keys in a nested dictionary) cannot be regular expressions.

# %% [markdown]
# Count each values in the `country1` list to know how many country codes to convert in the replace dictionary

# %%
ISO3166 = {
	'AD': 'Andorra',
	'AE': 'United Arab Emirates',
	'AF': 'Afghanistan',
	'AG': 'Antigua & Barbuda',
	'AI': 'Anguilla',
	'AL': 'Albania',
	'AM': 'Armenia',
	'AN': 'Netherlands Antilles',
	'AO': 'Angola',
	'AQ': 'Antarctica',
	'AR': 'Argentina',
	'AS': 'American Samoa',
	'AT': 'Austria',
	'AU': 'Australia',
	'AW': 'Aruba',
	'AZ': 'Azerbaijan',
	'BA': 'Bosnia and Herzegovina',
	'BB': 'Barbados',
	'BD': 'Bangladesh',
	'BE': 'Belgium',
	'BF': 'Burkina Faso',
	'BG': 'Bulgaria',
	'BH': 'Bahrain',
	'BI': 'Burundi',
	'BJ': 'Benin',
	'BM': 'Bermuda',
	'BN': 'Brunei Darussalam',
	'BO': 'Bolivia',
	'BR': 'Brazil',
	'BS': 'Bahama',
	'BT': 'Bhutan',
	'BU': 'Burma (no longer exists)',
	'BV': 'Bouvet Island',
	'BW': 'Botswana',
	'BY': 'Belarus',
	'BZ': 'Belize',
	'CA': 'Canada',
	'CC': 'Cocos (Keeling) Islands',
	'CF': 'Central African Republic',
	'CG': 'Congo',
	'CH': 'Switzerland',
	'CI': 'Côte D\'ivoire (Ivory Coast)',
	'CK': 'Cook Iislands',
	'CL': 'Chile',
	'CM': 'Cameroon',
	'CN': 'China',
	'CO': 'Colombia',
	'CR': 'Costa Rica',
	'CS': 'Czechoslovakia (no longer exists)',
	'CU': 'Cuba',
	'CV': 'Cape Verde',
	'CX': 'Christmas Island',
	'CY': 'Cyprus',
	'CZ': 'Czech Republic',
	'DD': 'German Democratic Republic (no longer exists)',
	'DE': 'Germany',
	'DJ': 'Djibouti',
	'DK': 'Denmark',
	'DM': 'Dominica',
	'DO': 'Dominican Republic',
	'DZ': 'Algeria',
	'EC': 'Ecuador',
	'EE': 'Estonia',
	'EG': 'Egypt',
	'EH': 'Western Sahara',
	'ER': 'Eritrea',
	'ES': 'Spain',
	'ET': 'Ethiopia',
	'FI': 'Finland',
	'FJ': 'Fiji',
	'FK': 'Falkland Islands (Malvinas)',
	'FM': 'Micronesia',
	'FO': 'Faroe Islands',
	'FR': 'France',
	'FX': 'France, Metropolitan',
	'GA': 'Gabon',
	'GB': 'United Kingdom',
	'GD': 'Grenada',
	'GE': 'Georgia',
	'GF': 'French Guiana',
	'GH': 'Ghana',
	'GI': 'Gibraltar',
	'GL': 'Greenland',
	'GM': 'Gambia',
	'GN': 'Guinea',
	'GP': 'Guadeloupe',
	'GQ': 'Equatorial Guinea',
	'GR': 'Greece',
	'GS': 'South Georgia and the South Sandwich Islands',
	'GT': 'Guatemala',
	'GU': 'Guam',
	'GW': 'Guinea-Bissau',
	'GY': 'Guyana',
	'HK': 'Hong Kong',
	'HM': 'Heard & McDonald Islands',
	'HN': 'Honduras',
	'HR': 'Croatia',
	'HT': 'Haiti',
	'HU': 'Hungary',
	'ID': 'Indonesia',
	'IE': 'Ireland',
	'IL': 'Israel',
	'IN': 'India',
	'IO': 'British Indian Ocean Territory',
	'IQ': 'Iraq',
	'IR': 'Islamic Republic of Iran',
	'IS': 'Iceland',
	'IT': 'Italy',
	'JM': 'Jamaica',
	'JO': 'Jordan',
	'JP': 'Japan',
	'KE': 'Kenya',
	'KG': 'Kyrgyzstan',
	'KH': 'Cambodia',
	'KI': 'Kiribati',
	'KM': 'Comoros',
	'KN': 'St. Kitts and Nevis',
	'KP': 'Korea, Democratic People\'s Republic of',
	'KR': 'Korea, Republic of',
	'KW': 'Kuwait',
	'KY': 'Cayman Islands',
	'KZ': 'Kazakhstan',
	'LA': 'Lao People\'s Democratic Republic',
	'LB': 'Lebanon',
	'LC': 'Saint Lucia',
	'LI': 'Liechtenstein',
	'LK': 'Sri Lanka',
	'LR': 'Liberia',
	'LS': 'Lesotho',
	'LT': 'Lithuania',
	'LU': 'Luxembourg',
	'LV': 'Latvia',
	'LY': 'Libyan Arab Jamahiriya',
	'MA': 'Morocco',
	'MC': 'Monaco',
	'MD': 'Moldova, Republic of',
	'MG': 'Madagascar',
	'MH': 'Marshall Islands',
	'ML': 'Mali',
	'MN': 'Mongolia',
	'MM': 'Myanmar',
	'MO': 'Macau',
	'MP': 'Northern Mariana Islands',
	'MQ': 'Martinique',
	'MR': 'Mauritania',
	'MS': 'Monserrat',
	'MT': 'Malta',
	'MU': 'Mauritius',
	'MV': 'Maldives',
	'MW': 'Malawi',
	'MX': 'Mexico',
	'MY': 'Malaysia',
	'MZ': 'Mozambique',
	'NA': 'Namibia',
	'NC': 'New Caledonia',
	'NE': 'Niger',
	'NF': 'Norfolk Island',
	'NG': 'Nigeria',
	'NI': 'Nicaragua',
	'NL': 'Netherlands',
	'NO': 'Norway',
	'NP': 'Nepal',
	'NR': 'Nauru',
	'NT': 'Neutral Zone (no longer exists)',
	'NU': 'Niue',
	'NZ': 'New Zealand',
	'OM': 'Oman',
	'PA': 'Panama',
	'PE': 'Peru',
	'PF': 'French Polynesia',
	'PG': 'Papua New Guinea',
	'PH': 'Philippines',
	'PK': 'Pakistan',
	'PL': 'Poland',
	'PM': 'St. Pierre & Miquelon',
	'PN': 'Pitcairn',
	'PR': 'Puerto Rico',
	'PT': 'Portugal',
	'PW': 'Palau',
	'PY': 'Paraguay',
	'QA': 'Qatar',
	'RE': 'Réunion',
	'RO': 'Romania',
	'RU': 'Russian Federation',
	'RW': 'Rwanda',
	'SA': 'Saudi Arabia',
	'SB': 'Solomon Islands',
	'SC': 'Seychelles',
	'SD': 'Sudan',
	'SE': 'Sweden',
	'SG': 'Singapore',
	'SH': 'St. Helena',
	'SI': 'Slovenia',
	'SJ': 'Svalbard & Jan Mayen Islands',
	'SK': 'Slovakia',
	'SL': 'Sierra Leone',
	'SM': 'San Marino',
	'SN': 'Senegal',
	'SO': 'Somalia',
	'SR': 'Suriname',
	'ST': 'Sao Tome & Principe',
	'SU': 'Union of Soviet Socialist Republics (no longer exists)',
	'SV': 'El Salvador',
	'SY': 'Syrian Arab Republic',
	'SZ': 'Swaziland',
	'TC': 'Turks & Caicos Islands',
	'TD': 'Chad',
	'TF': 'French Southern Territories',
	'TG': 'Togo',
	'TH': 'Thailand',
	'TJ': 'Tajikistan',
	'TK': 'Tokelau',
	'TM': 'Turkmenistan',
	'TN': 'Tunisia',
	'TO': 'Tonga',
	'TP': 'East Timor',
	'TR': 'Turkey',
	'TT': 'Trinidad & Tobago',
	'TV': 'Tuvalu',
	'TW': 'Taiwan, Province of China',
	'TZ': 'Tanzania, United Republic of',
	'UA': 'Ukraine',
	'UG': 'Uganda',
	'UM': 'United States Minor Outlying Islands',
	'US': 'United States of America',
	'UY': 'Uruguay',
	'UZ': 'Uzbekistan',
	'VA': 'Vatican City State (Holy See)',
	'VC': 'St. Vincent & the Grenadines',
	'VE': 'Venezuela',
	'VG': 'British Virgin Islands',
	'VI': 'United States Virgin Islands',
	'VN': 'Viet Nam',
	'VU': 'Vanuatu',
	'WF': 'Wallis & Futuna Islands',
	'WS': 'Samoa',
	'YD': 'Democratic Yemen (no longer exists)',
	'YE': 'Yemen',
	'YT': 'Mayotte',
	'YU': 'Yugoslavia',
	'ZA': 'South Africa',
	'ZM': 'Zambia',
	'ZR': 'Zaire',
	'ZW': 'Zimbabwe'}

# %%
TrowBus1913 = TrowBus1913.replace({'country1_api': ISO3166})
TrowBus1913 = TrowBus1913.replace({'country2_api': ISO3166})

# %%
TrowBus1913.to_csv(r'1913TrowBus_nationalityAPI.csv', index = False)
